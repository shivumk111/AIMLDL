# %% [markdown]
# <a href="https://colab.research.google.com/github/shivumk111/msk/blob/master/upload_local_github_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Access Local Drive**

# %% [markdown]
# copy and paste in file explorer to watch video on
#
# How to upload a local drive ipynb file and csv file.
#
#
# E:\dataAnalysis\colab\Upload_OpenFileFromLocalDrive.mp4

# %% [markdown]
# ##**Load and Access Files from GitHub Repository**

# %%
# !git clone https://github.com/shivumk111/deep_learning.git
# Out:
# Cloning into 'deep_learning'...
# remote: Enumerating objects: 2516, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 2516 (delta 5), reused 23 (delta 3), pack-reused 2488
# Receiving objects: 100% (2516/2516), 289.22 MiB | 29.73 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Checking out files: 100% (2413/2413), done.

# %%
import pandas as pd

# %%
data = pd.read_csv('deep_learning/Plotting/mobile_cleaned.csv')
data.head()
# Out:
#    sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0         0        12        55  ...              2000             125         1
# 1         0         1        55  ...              2000             165         1
# 2         0         9        55  ...              2500             164         0
# 3         0         8        55  ...              3000             165         1
# 4         1         1        55  ...              3000             165         0
#
# [5 rows x 40 columns]

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 72596, done.
# remote: Counting objects: 100% (70104/70104), done.
# remote: Compressing objects: 100% (70093/70093), done.
# remote: Total 72596 (delta 35), reused 70050 (delta 8), pack-reused 2492
# Receiving objects: 100% (72596/72596), 121.68 MiB | 29.82 MiB/s, done.
# Resolving deltas: 100% (96/96), done.
# Checking out files: 100% (3002/3002), done.

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("machine_learning/OpenCv/images/bb.JPG")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x270 at 0x7FC72E05F610>
